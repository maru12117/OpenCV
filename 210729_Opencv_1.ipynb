# %%
import tensorflow as tf

# %%
tf.__version__
# Out:
# '2.5.0'

# %%
pip install opencv-python
# Out:
# Collecting opencv-python
#   Downloading opencv_python-4.5.3.56-cp37-cp37m-win_amd64.whl (34.9 MB)
# Requirement already satisfied: numpy>=1.14.5 in c:\users\pc\.conda\envs\hp_8_8\lib\site-packages (from opencv-python) (1.19.5)
# Installing collected packages: opencv-python
# Successfully installed opencv-python-4.5.3.56
# Note: you may need to restart the kernel to use updated packages.

# %%
import cv2

# %%
cv2.__version__
# Out:
# '4.5.3'

# %%
import numpy as np
import cv2

image=np.zeros((300,400), np.uint8)
image[:]=200

title1, title2 = "Position1",'Position2'

cv2.namedWindow(title1, cv2.WINDOW_AUTOSIZE)
cv2.namedWindow(title2)
cv2.moveWindow(title1, 150, 150)
cv2.moveWindow(title2, 400, 50)


cv2.imshow(title1, image)
cv2.imshow(title2, image)
cv2.waitKey(0)

cv2.destroyAllWindows()

# %%
import numpy as np
import cv2

image=np.zeros((200,300), np.uint8)
image.fill(255)
image[:100]=100

title1, title2 = "AUTOSIZE", "NORMAL" #윈도우 이름.
cv2.namedWindow(title1, cv2.WINDOW_AUTOSIZE)
cv2.namedWindow(title2, cv2.WINDOW_NORMAL)

cv2.imshow(title1, image)
cv2.imshow(title2, image)
cv2.resizeWindow(title1, 400, 300)
cv2.resizeWindow(title2, 400, 300)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
#키 이벤트 발생

import numpy as np
import cv2

switch_case = {
    ord('a'):"a키 입력", #ord 함수 -문자를 아스키코드로 변환
    ord('b'):"b키 입력",
    0x41:"A키 입력",
    int('0x42', 16):"B키 입력",
    2424832 :"왼쪽 화살표키 입력",
    2490368 : "윗쪽 화살표키 입력",
    2555904 : "오른쪽 화살표 키 입력",
    2621440: "아래쪽 화살표 키 입력"
    }

image = np.ones((200,300), np.uint8) #화소값이 1인 행렬 생성
cv2.namedWindow("Keyboard Event")
cv2.imshow("Keyboard Event", image)

while True: #무한반복
    key = cv2.waitKeyEx(100) #100ms 동안 키 이벤트 대기
    if key == 27:
        break #ESC 누르면 종료
    try:
        result = switch_case[key]
        print(result)
    except KeyError:
        result = -1

cv2.destroyAllWindows() #열린 모든 윈도우 제거
# Out:
# 오른쪽 화살표 키 입력
# 왼쪽 화살표키 입력
# 아래쪽 화살표 키 입력
# 왼쪽 화살표키 입력
# 윗쪽 화살표키 입력
# 오른쪽 화살표 키 입력
# 윗쪽 화살표키 입력
# 윗쪽 화살표키 입력
# 아래쪽 화살표 키 입력
# 아래쪽 화살표 키 입력
# 왼쪽 화살표키 입력
# 윗쪽 화살표키 입력
# a키 입력
# b키 입력
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-3-8589a2ef62e3> in <module>
#      20
#      21 while True: #무한반복
# ---> 22     key = cv2.waitKeyEx(100) #100ms 동안 키 이벤트 대기
#      23     if key == 27:
#      24         break #ESC 누르면 종료
#
# KeyboardInterrupt:

# %%
#마우스 이벤트

import numpy as np
import cv2

def onMouse(event, x,y, flags, param):
    if event == cv2.EVENT_LBUTTONDOWN:
        print("마우스 왼쪽 버튼 누르기")
    elif event ==cv2.EVENT_RBUTTONDOWN:
        print("마우스 오른쪽 버튼 누르기")
    elif event ==cv2.EVENT_RBUTTONUP:
        print("마우스 오른쪽 버튼 떼기")
    elif event ==cv2.EVENT_LBUTTONDBLCLK:
        print("마우스 왼쪽  버튼 더블클릭")

image = np.full((200,300),355, np.uint8)

title1, title2 = "Mouse Event1", "Mouse Event2"
cv2.imshow(title1, image)
cv2.imshow(title2, image)

cv2.setMouseCallback("Mouse Event1", onMouse)
cv2.waitKey(0)
cv2.destroyAllWindows()
# Out:
# 마우스 왼쪽 버튼 누르기
# 마우스 오른쪽 버튼 누르기
# 마우스 오른쪽 버튼 떼기
# 마우스 왼쪽 버튼 누르기
# 마우스 오른쪽 버튼 누르기
# 마우스 오른쪽 버튼 떼기
# 마우스 왼쪽 버튼 누르기

# %%
#트랙바

import numpy as np
import cv2

def onChange(value): #트랙바 콜백 함수
    global image
    print("value 값:", value)
    image = np.zeros((300,500), np.uint8) #영상 data초기화
    image = image+value #행렬과 스칼라 덧셈 수행
    cv2.imshow(title, image)

image = np.zeros((300, 500), np.uint8) #영상 생성

title = "Trackbat Event"
cv2.imshow(title, image)

cv2.createTrackbar("Brightness", title, image[0][0], 255, onChange) #현재값, 최대값, 콜백함수
cv2.waitKey(0)
cv2.destroyAllWindows()
# Out:
# value 값: 1
# value 값: 2
# value 값: 3
# value 값: 5
# value 값: 6
# value 값: 8
# value 값: 9
# value 값: 12
# value 값: 14
# value 값: 16
# value 값: 17
# value 값: 21
# value 값: 23
# value 값: 26
# value 값: 28
# value 값: 32
# value 값: 34
# value 값: 36
# value 값: 38
# value 값: 42
# value 값: 44
# value 값: 47
# value 값: 49
# value 값: 51
# value 값: 53
# value 값: 55
# value 값: 56
# value 값: 57
# value 값: 59
# value 값: 61
# value 값: 62
# value 값: 63
# value 값: 64
# value 값: 65
# value 값: 66
# value 값: 67
# value 값: 68
# value 값: 69
# value 값: 70
# value 값: 71
# value 값: 72
# value 값: 73
# value 값: 74
# value 값: 75
# value 값: 76
# value 값: 77
# value 값: 78
# value 값: 79
# value 값: 80
# value 값: 81
# value 값: 82
# value 값: 83
# value 값: 84
# value 값: 85
# value 값: 86
# value 값: 87
# value 값: 88
# value 값: 90
# value 값: 91
# value 값: 93
# value 값: 94
# value 값: 95
# value 값: 96
# value 값: 97
# value 값: 98
# value 값: 99
# value 값: 100
# value 값: 101
# value 값: 102
# value 값: 101
# value 값: 100
# value 값: 99
# value 값: 97
# value 값: 96
# value 값: 95
# value 값: 93
# value 값: 92
# value 값: 90
# value 값: 88
# value 값: 87
# value 값: 85
# value 값: 84
# value 값: 82
# value 값: 80
# value 값: 79
# value 값: 77
# value 값: 76
# value 값: 75
# value 값: 74
# value 값: 73
# value 값: 72
# value 값: 71
# value 값: 70
# value 값: 69
# value 값: 68
# value 값: 67
# value 값: 66
# value 값: 65
# value 값: 64
# value 값: 62
# value 값: 61
# value 값: 60
# value 값: 59
# value 값: 57
# value 값: 56
# value 값: 55
# value 값: 54
# value 값: 53
# value 값: 52
# value 값: 51
# value 값: 50
# value 값: 49
# value 값: 48
# value 값: 47
# value 값: 46
# value 값: 45
# value 값: 44
# value 값: 43
# value 값: 42
# value 값: 41
# value 값: 40
# value 값: 39
# value 값: 38
# value 값: 37
# value 값: 36
# value 값: 35
# value 값: 34
# value 값: 33
# value 값: 32
# value 값: 31
# value 값: 30
# value 값: 29
# value 값: 28
# value 값: 27
# value 값: 26
# value 값: 25

# %%
#트랙바 + mouse

import numpy as np
import cv2

def onChange(value): #트랙바 콜백 함수
    global image
    print("value 값:", value)
    image = np.zeros((300,500), np.uint8) #영상 data초기화
    image = image+value #행렬과 스칼라 덧셈 수행
    cv2.imshow(title, image)

def onMouse(event, x,y, flags, param):
    global image, bar_name
    if event ==cv2.EVENT_RBUTTONDOWN:
        if (image[0][0]<246): image=image+10
        cv2.setTrackbarPos(bar_name, title, image[0][0])
        cv2.imshow(title, image)

    elif event ==cv2.EVENT_LBUTTONDOWN:
        if(image[0][0] >=10): image = image-10
        cv2.setTrackbarPos(bar_name, title, image[0][0])
        cv2.imshow(title, image)
                           

image = np.zeros((300, 500), np.uint8) #영상 생성

title = "Trackbat Event & Mouse Event"
bar_name = "Brightness"
cv2.imshow(title, image)

cv2.createTrackbar(bar_name, title, image[0][0], 255, onChange) #현재값, 최대값, 콜백함수
cv2.setMouseCallback(title, onMouse)
cv2.waitKey(0)
cv2.destroyAllWindows()
# Out:
# value 값: 2
# value 값: 4
# value 값: 6
# value 값: 8
# value 값: 10
# value 값: 11
# value 값: 12
# value 값: 14
# value 값: 15
# value 값: 16
# value 값: 17
# value 값: 18
# value 값: 19
# value 값: 20
# value 값: 22
# value 값: 23
# value 값: 24
# value 값: 25
# value 값: 26
# value 값: 27
# value 값: 28
# value 값: 29
# value 값: 31
# value 값: 32
# value 값: 33
# value 값: 34
# value 값: 35
# value 값: 36
# value 값: 38
# value 값: 39
# value 값: 40
# value 값: 41
# value 값: 42
# value 값: 43
# value 값: 44
# value 값: 46
# value 값: 47
# value 값: 48
# value 값: 49
# value 값: 50
# value 값: 51
# value 값: 52
# value 값: 53
# value 값: 54
# value 값: 55
# value 값: 56
# value 값: 57
# value 값: 58
# value 값: 59
# value 값: 60
# value 값: 61
# value 값: 63
# value 값: 64
# value 값: 65
# value 값: 66
# value 값: 67
# value 값: 68
# value 값: 69
# value 값: 70
# value 값: 69
# value 값: 68
# value 값: 67
# value 값: 66
# value 값: 65
# value 값: 64
# value 값: 62
# value 값: 60
# value 값: 59
# value 값: 57
# value 값: 56
# value 값: 54
# value 값: 53
# value 값: 52
# value 값: 50
# value 값: 49
# value 값: 48
# value 값: 47
# value 값: 46
# value 값: 45
# value 값: 44
# value 값: 43
# value 값: 42
# value 값: 41
# value 값: 39
# value 값: 38
# value 값: 37
# value 값: 36
# value 값: 35
# value 값: 34
# value 값: 33
# value 값: 32
# value 값: 31
# value 값: 30
# value 값: 29
# value 값: 28

# %%
#예제
#마우스 오른쪽 버튼을 클릭하면 영상이 검정색으로
#마우스 왼쪽 버튼을 클릭하면 영상이 백색으로..

import numpy as np
import cv2

def onChange(value): #트랙바 콜백 함수
    global image, title
    print("value 값:", value)
    image = np.zeros((300,500), np.uint8) #영상 data초기화
    image = image+value #행렬과 스칼라 덧셈 수행
    cv2.imshow(title, image)

def onMouse(event, x,y, flags, param):
    global image, bar_name
    if event ==cv2.EVENT_LBUTTONDOWN:
        image.fill(0)
        cv2.setTrackbarPos(bar_name, title, image[0][0])
        cv2.imshow(title, image)

    elif event ==cv2.EVENT_RBUTTONDOWN:
        image.fill(255)
        cv2.setTrackbarPos(bar_name, title, image[0][0])
        cv2.imshow(title, image)
                           

image = np.zeros((300, 500), np.uint8) #영상 생성

title = "Trackbat Event & Mouse Event"
bar_name = "Brightness"
cv2.imshow(title, image)

cv2.createTrackbar(bar_name, title, image[0][0], 255, onChange) #현재값, 최대값, 콜백함수
cv2.setMouseCallback(title, onMouse)
cv2.waitKey(0)
cv2.destroyAllWindows()
# Out:
# value 값: 1
# value 값: 2
# value 값: 4
# value 값: 5
# value 값: 7
# value 값: 8
# value 값: 10
# value 값: 11
# value 값: 12
# value 값: 13
# value 값: 14
# value 값: 16
# value 값: 17
# value 값: 18
# value 값: 20
# value 값: 21
# value 값: 23
# value 값: 24
# value 값: 25
# value 값: 26
# value 값: 27
# value 값: 28
# value 값: 29
# value 값: 31
# value 값: 32
# value 값: 33
# value 값: 34
# value 값: 35
# value 값: 34
# value 값: 33
# value 값: 32
# value 값: 31
# value 값: 30
# value 값: 29
# value 값: 28
# value 값: 27
# value 값: 26
# value 값: 25
# value 값: 24
# value 값: 23
# value 값: 22
# value 값: 21
# value 값: 20
# value 값: 19
# value 값: 18
# value 값: 17
# value 값: 16
# value 값: 15
# value 값: 14
# value 값: 255
# value 값: 0
# value 값: 255
# value 값: 0
# value 값: 255
# value 값: 0
# value 값: 255
# value 값: 0
# value 값: 255
